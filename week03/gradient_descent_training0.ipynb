# %% [markdown]
# <a href="https://colab.research.google.com/github/reitezuz/18NES1-2026/blob/main/week03/gradient_descent_training0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Gradient Descent Training
#
# In this notebook, we implement the gradient descent learning algorithm for a linear neuron.
#
# Unlike the Rosenblatt perceptron, where weights are updated only when the model makes a mistake, gradient descent updates the weights **at every step** based on the value of the error.
#
# The goal is to understand that training a neural model can be formulated as an optimization problem:
# we iteratively minimize a loss function (Mean Squared Error).
#
# ---
#
# ### Main Task
#
# You are given a skeleton of the `gradient_descent` method.
#
# **Complete the missing parts:**
# - compute the predicted output (forward pass),
# - calculate the error,
# - update the weights and bias using the gradient update rule,
# - compute the Mean Squared Error after each epoch.
#
# ---
#
# ### What You Should Observe
#
# - The weights are updated gradually (not only when classification is wrong).
# - The learning rate controls the size of the update step.
# - Different learning rates may lead to slow convergence or divergence.

# %%
import numpy as np

class LinearNeuron:
    def __init__(self, weights=None, bias=0) -> None:
        if weights is None:
            self.weights = np.random.randn(1)
        else:
            self.weights = np.array(weights)
        self.bias = bias

    def internal_potential(self, inputs)  -> float:
        return np.dot(inputs, self.weights) + self.bias

    def activation(self, xi): # identity
        return xi

    def forward(self, inputs) -> float:
        potential = self.internal_potential(inputs)
        return self.activation(potential)

    def gradient_descent(self, X, d, learning_rate=0.01, epochs=100):
        """
        Stochastic gradient descent  for linear neuron (MSE loss) – to be completed.
        """

        n_samples = len(X)
        training_errors = []

        for epoch in range(epochs):

            # 1) Shuffle data
            indices = np.random.permutation(n_samples)
            X = X[indices]
            d = d[indices]

            for inputs, true_output in zip(X, d):

                # 2) Forward pass
                prediction = ...
                # 3) Compute error (SSE)
                error = ...

                # 4) Update weights
                self.weights += ...

                # 5) Update bias
                self.bias += ...

            # 6) Compute MSE for whole dataset
            mse = ...
            training_errors.append(mse)
            print(f"Epoch {epoch+1}/{epochs} - MSE: {mse:.6f} weights: {self.weights} bias: {self.bias}")


        return training_errors

    def __str__(self) -> str:
        return f"Perceptron(weights={self.weights}, bias={self.bias})"

def MSE(d, y):
    return np.mean((d - y)**2)

# %% [markdown]
# ### Running the example
#
# - Train the linear neuron on the given dataset.
# - Observe the training results:
#   - final weight and bias,
#   - predicted outputs,
#   - overall Mean Squared Error (MSE).
# - Experiment by modifying:
#   - the training data,
#   - initial weights and bias,
#   - learning rate,
#   - number of epochs.

# %%
# Small editable dataset ... corresponds to y = 2x + 1

X = np.array([
    [-2.0],
    [-1.0],
    [ 0.0],
    [ 1.0],
    [ 2.0]
])

d = np.array([
    -3.0,   # for x = -2
    -1.0,   # for x = -1
     1.0,   # for x =  0
     3.0,   # for x =  1
     5.0    # for x =  2
])

# %%
model = LinearNeuron(weights=np.array([0.0]), bias=0.0)
#model = LinearNeuron()

print("Before training:")
print(model)

errors = model.gradient_descent(X, d, learning_rate=0.01, epochs=100)

print("\nAfter training:")
print(model)
print(f"Final MSE: {errors[-1]:f}")

# Compare the true and predicted outputs
import pandas as pd
df = pd.DataFrame(columns=['Input', 'Predicted', 'True'])
y = model.forward(X)
for inputs, true_output, predicted_output in zip(X, d, y):
    df.loc[len(df)] = {'Input': inputs, 'Predicted': predicted_output, 'True': true_output}
df
# Out:
# Before training:
# Perceptron(weights=[0.], bias=0.0)
# Epoch 1/100 - MSE: 7.425466 weights: [0.19386588] bias: 0.050671060000000004
# Epoch 2/100 - MSE: 6.128862 weights: [0.37031033] bias: 0.09607253779193786
# Epoch 3/100 - MSE: 5.067352 weights: [0.52875348] bias: 0.1408032596289944
# Epoch 4/100 - MSE: 4.194621 weights: [0.67203881] bias: 0.18289576509077624
# Epoch 5/100 - MSE: 3.476626 weights: [0.80162416] bias: 0.222557547045735
# Epoch 6/100 - MSE: 2.887569 weights: [0.91782633] bias: 0.26150887461994193
# Epoch 7/100 - MSE: 2.402060 weights: [1.02280883] bias: 0.29839147813007333
# Epoch 8/100 - MSE: 2.001566 weights: [1.11760804] bias: 0.3334157272485334
# Epoch 9/100 - MSE: 1.670913 weights: [1.20319309] bias: 0.3666671709906763
# Epoch 10/100 - MSE: 1.396271 weights: [1.28140785] bias: 0.3970728118537739
# Epoch 11/100 - MSE: 1.169986 weights: [1.35138811] bias: 0.4267712436642686
# Epoch 12/100 - MSE: 0.982556 weights: [1.41450162] bias: 0.4550784927437395
# Epoch 13/100 - MSE: 0.826572 weights: [1.47190714] bias: 0.4815333632636236
# Epoch 14/100 - MSE: 0.697716 weights: [1.52294558] bias: 0.5075023139736545
# Epoch 15/100 - MSE: 0.590022 weights: [1.56942181] bias: 0.5317836245363986
# Epoch 16/100 - MSE: 0.500064 weights: [1.6115569] bias: 0.5547048421568643
# Epoch 17/100 - MSE: 0.425211 weights: [1.64914594] bias: 0.576899529312125
# Epoch 18/100 - MSE: 0.362509 weights: [1.68304929] bias: 0.5980135433588157
# Epoch 19/100 - MSE: 0.309634 weights: [1.71406036] bias: 0.6177555932771801
# Epoch 20/100 - MSE: 0.265479 weights: [1.74145622] bias: 0.636972777012427
# Epoch 21/100 - MSE: 0.227928 weights: [1.76680634] bias: 0.6547903276918048
# Epoch 22/100 - MSE: 0.196358 weights: [1.78934145] bias: 0.6719697233305757
# Epoch 23/100 - MSE: 0.169417 weights: [1.81020532] bias: 0.6879539483329469
# Epoch 24/100 - MSE: 0.146639 weights: [1.82881095] bias: 0.7033057994419255
# Epoch 25/100 - MSE: 0.127248 weights: [1.84562735] bias: 0.7178900375398618
# Epoch 26/100 - MSE: 0.110790 weights: [1.86047185] bias: 0.7319438581781198
# Epoch 27/100 - MSE: 0.096625 weights: [1.87414163] bias: 0.7451578134041632
# Epoch 28/100 - MSE: 0.084462 weights: [1.88652793] bias: 0.7576979780430337
# Epoch 29/100 - MSE: 0.074011 weights: [1.89765515] bias: 0.7696469775239261
# Epoch 30/100 - MSE: 0.065026 weights: [1.90753543] bias: 0.781078783031749
# Epoch 31/100 - MSE: 0.057249 weights: [1.91643859] bias: 0.7919515873149061
# Epoch 32/100 - MSE: 0.050504 weights: [1.92444166] bias: 0.8022980900899819
# Epoch 33/100 - MSE: 0.044604 weights: [1.93190283] bias: 0.8120389296789482
# Epoch 34/100 - MSE: 0.039469 weights: [1.93859729] bias: 0.8213159833784313
# Epoch 35/100 - MSE: 0.034982 weights: [1.94465425] bias: 0.8301301670261504
# Epoch 36/100 - MSE: 0.031058 weights: [1.95008563] bias: 0.8385227908045448
# Epoch 37/100 - MSE: 0.027613 weights: [1.95500193] bias: 0.8464960836891422
# Epoch 38/100 - MSE: 0.024596 weights: [1.95928656] bias: 0.8541199635149893
# Epoch 39/100 - MSE: 0.021923 weights: [1.9633298] bias: 0.8613163651709219
# Epoch 40/100 - MSE: 0.019563 weights: [1.96697657] bias: 0.8681591735428531
# Epoch 41/100 - MSE: 0.017479 weights: [1.97022552] bias: 0.8746750266932255
# Epoch 42/100 - MSE: 0.015640 weights: [1.97302215] bias: 0.8809000230017967
# Epoch 43/100 - MSE: 0.014005 weights: [1.97557572] bias: 0.8868107464835202
# Epoch 44/100 - MSE: 0.012551 weights: [1.97786301] bias: 0.89243133325061
# Epoch 45/100 - MSE: 0.011255 weights: [1.97995264] bias: 0.8977684674154603
# Epoch 46/100 - MSE: 0.010101 weights: [1.98181263] bias: 0.9028450282213308
# Epoch 47/100 - MSE: 0.009066 weights: [1.98361909] bias: 0.907646935131587
# Epoch 48/100 - MSE: 0.008145 weights: [1.9851574] bias: 0.9122274912758965
# Epoch 49/100 - MSE: 0.007319 weights: [1.98661769] bias: 0.9165691306695292
# Epoch 50/100 - MSE: 0.006582 weights: [1.98786168] bias: 0.92070722116468
# Epoch 51/100 - MSE: 0.005919 weights: [1.98911139] bias: 0.9246204809451634
# Epoch 52/100 - MSE: 0.005328 weights: [1.9901257] bias: 0.9283577332401856
# Epoch 53/100 - MSE: 0.004796 weights: [1.99109303] bias: 0.9319030919699346
# Epoch 54/100 - MSE: 0.004318 weights: [1.99201253] bias: 0.9352661251783794
# Epoch 55/100 - MSE: 0.003889 weights: [1.99282088] bias: 0.938466269841799
# Epoch 56/100 - MSE: 0.003505 weights: [1.99351936] bias: 0.941512188449171
# Epoch 57/100 - MSE: 0.003159 weights: [1.99411539] bias: 0.9444108568060366
# Epoch 58/100 - MSE: 0.002848 weights: [1.9947202] bias: 0.9471588192340245
# Epoch 59/100 - MSE: 0.002568 weights: [1.99527925] bias: 0.9497690732817041
# Epoch 60/100 - MSE: 0.002316 weights: [1.99573376] bias: 0.9522560237526847
# Epoch 61/100 - MSE: 0.002089 weights: [1.99613912] bias: 0.9546201693192771
# Epoch 62/100 - MSE: 0.001885 weights: [1.9964749] bias: 0.9568692180573459
# Epoch 63/100 - MSE: 0.001701 weights: [1.99684299] bias: 0.959001926666247
# Epoch 64/100 - MSE: 0.001535 weights: [1.99711451] bias: 0.9610335518970261
# Epoch 65/100 - MSE: 0.001385 weights: [1.99741039] bias: 0.9629612145646984
# Epoch 66/100 - MSE: 0.001250 weights: [1.99767293] bias: 0.9647937758804618
# Epoch 67/100 - MSE: 0.001129 weights: [1.99787869] bias: 0.9665376783699574
# Epoch 68/100 - MSE: 0.001019 weights: [1.99810136] bias: 0.9681928873859772
# Epoch 69/100 - MSE: 0.000920 weights: [1.99826725] bias: 0.9697682875707497
# Epoch 70/100 - MSE: 0.000831 weights: [1.99841803] bias: 0.9712656292511663
# Epoch 71/100 - MSE: 0.000750 weights: [1.99859702] bias: 0.9726861966605351
# Epoch 72/100 - MSE: 0.000677 weights: [1.99871753] bias: 0.9740389199456752
# Epoch 73/100 - MSE: 0.000612 weights: [1.99883709] bias: 0.975324228038979
# Epoch 74/100 - MSE: 0.000552 weights: [1.99893108] bias: 0.9765462741636755
# Epoch 75/100 - MSE: 0.000499 weights: [1.99902577] bias: 0.9777076307795821
# Epoch 76/100 - MSE: 0.000450 weights: [1.99913359] bias: 0.9788104258100366
# Epoch 77/100 - MSE: 0.000407 weights: [1.99919311] bias: 0.9798598343404767
# Epoch 78/100 - MSE: 0.000368 weights: [1.99926368] bias: 0.9808570681784573
# Epoch 79/100 - MSE: 0.000332 weights: [1.99934647] bias: 0.9818041119101855
# Epoch 80/100 - MSE: 0.000300 weights: [1.99941187] bias: 0.9827047732235639
# Epoch 81/100 - MSE: 0.000271 weights: [1.99948401] bias: 0.9835601301706239
# Epoch 82/100 - MSE: 0.000245 weights: [1.99954065] bias: 0.9843736836789104
# Epoch 83/100 - MSE: 0.000221 weights: [1.99958986] bias: 0.9851470159336214
# Epoch 84/100 - MSE: 0.000200 weights: [1.99961384] bias: 0.9858823539164338
# Epoch 85/100 - MSE: 0.000180 weights: [1.99965566] bias: 0.9865810367603378
# Epoch 86/100 - MSE: 0.000163 weights: [1.99967861] bias: 0.987245368993144
# Epoch 87/100 - MSE: 0.000147 weights: [1.99969868] bias: 0.987876828165971
# Epoch 88/100 - MSE: 0.000133 weights: [1.99972922] bias: 0.9884769163588
# Epoch 89/100 - MSE: 0.000120 weights: [1.99974779] bias: 0.9890474495275009
# Epoch 90/100 - MSE: 0.000108 weights: [1.99976912] bias: 0.9895896552781769
# Epoch 91/100 - MSE: 0.000098 weights: [1.99980272] bias: 0.9901044964116122
# Epoch 92/100 - MSE: 0.000089 weights: [1.99981608] bias: 0.9905943897985866
# Epoch 93/100 - MSE: 0.000080 weights: [1.99983205] bias: 0.9910599944292543
# Epoch 94/100 - MSE: 0.000072 weights: [1.99985611] bias: 0.9915022535350783
# Epoch 95/100 - MSE: 0.000065 weights: [1.99987992] bias: 0.9919225328870442
# Epoch 96/100 - MSE: 0.000059 weights: [1.9998924] bias: 0.9923223710236588
# Epoch 97/100 - MSE: 0.000053 weights: [1.99991183] bias: 0.9927021166279868
# Epoch 98/100 - MSE: 0.000048 weights: [1.99992613] bias: 0.993063199749482
# Epoch 99/100 - MSE: 0.000043 weights: [1.99992927] bias: 0.9934065805296045
# Epoch 100/100 - MSE: 0.000039 weights: [1.99993417] bias: 0.993732962404107
#
# After training:
# Perceptron(weights=[1.99993417], bias=0.993732962404107)
# Final MSE: 0.000039
#     Input  Predicted  True
# 0  [-2.0]  -3.006135  -3.0
# 1  [-1.0]  -1.006201  -1.0
# 2   [0.0]   0.993733   1.0
# 3   [1.0]   2.993667   3.0
# 4   [2.0]   4.993601   5.0
