# %% [markdown]
# <a href="https://colab.research.google.com/github/reitezuz/18NES1-2026/blob/main/wee05/geometric_shapes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

def generate_dataset(n_samples=1000, noise=0.01, random_state=42):

    rng = np.random.RandomState(random_state)

    # generate random points
    X = rng.uniform(-5, 5, size=(n_samples, 2))
    y = np.zeros(n_samples)

    for i, (x1, x2) in enumerate(X):

        # ----- rectangle -----
        if -3 < x1 < 3 and -3 < x2 < -1:
            y[i] = 1

        # ----- ellipse -----
        cx, cy = 3, 3
        a, b = 2, 1

        if ((x1 - cx)**2)/a**2 + ((x2 - cy)**2)/b**2 < 1:
            y[i] = 1

        # ----- spiral -----
        r = np.sqrt(x1**2 + x2**2)
        theta = np.arctan2(x2, x1)

        if abs(r - theta) < 0.5:
            y[i] = 1

    # add noise
    X += noise * rng.randn(*X.shape)

    return X, y.astype(int)

# %%
import matplotlib.pyplot as plt

def plot_dataset(X, y):

    plt.figure(figsize=(6,6))
    plt.scatter(X[:,0], X[:,1], c=y, cmap="coolwarm", s=10)
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title("Generated dataset")
    plt.show()

# %%
X, y = generate_dataset(2000)

plot_dataset(X, y)
